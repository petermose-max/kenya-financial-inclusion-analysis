# %% [markdown]
# # Kenya Financial Inclusion Analysis 2024
# ## Python Exploratory Data Analysis
#
# This stage converts the county-level scorecard into structured visual evidence for interpretation and decision-making. It focuses on ranking counties by overall financial inclusion, identifying regional disparities, and examining variation across gender, income quintiles, and financial health indicators. The analysis also highlights patterns of inclusion and exclusion across Kenya, allowing clear comparison between high-performing and low-performing counties. These outputs support evidence-based policy formulation, targeting of financial inclusion interventions, and strategic insights for financial service providers and fintech development.

# %%
# Shared paths keep scorecard inputs and figure outputs aligned for reporting.
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

PROJECT_ROOT = Path(r"C:\Portfolio\FinancialInclusion2024")
DATA_DIR = PROJECT_ROOT / "data"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
FIGURE_DIR = OUTPUT_DIR / "figures"

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
FIGURE_DIR.mkdir(parents=True, exist_ok=True)

SCORECARD_PATH = OUTPUT_DIR / "finaccess_county_scorecard_2024.csv"

if SCORECARD_PATH.exists():
    df_county_scorecard = pd.read_csv(SCORECARD_PATH)
    display(df_county_scorecard.head())
else:
    print(f"Run notebooks/02_sql_advanced.ipynb first to create: {SCORECARD_PATH}")
# Out:
#    county_code      county_name       region  respondent_count  avg_age_code  \
# 0           47          Nairobi      Nairobi               622          3.26
# 1           22           Kiambu      Central               541          3.68
# 2           14             Embu      Eastern               478          4.09
# 3           19            Nyeri      Central               457          4.02
# 4           28  Elgeyo-Marakwet  Rift Valley               426          3.68
#
#    working_age_share  male_share  female_share  avg_education_code  \
# 0              91.48       43.89         56.11                3.08
# 1              77.45       51.39         48.61                2.80
# 2              72.38       45.40         54.60                2.70
# 3              74.40       38.95         61.05                2.77
# 4              79.34       42.49         57.51                2.69
#
#    upper_education_share  ...  exclusion_rate  avg_finhealth_fnl  \
# ...

# %% [markdown]
# ## Analytical Focus
#
# The Python analysis uses the exported county scorecard to visualise county rankings, regional variation, gender gaps, income gradients, and financial health patterns. These outputs will make the findings easier to interpret for policy, programme, and product teams.
